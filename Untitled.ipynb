# %%
import pandas as pd

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')
sub = pd.read_csv('./data/sample_submission.csv')

# %%
job_code = pd.read_excel('./data/직업코드표.xlsx')

# %%
job_code
# Out:
#       직무 상위 코드    직무명  직무 코드  직무 키워드명
# 0           16  기획·전략   2205       기획
# 1           16  기획·전략   2225     경영관리
# 2           16  기획·전략   1652     경영분석
# 3           16  기획·전략   1624     게임기획
# 4           16  기획·전략   1625     경영기획
# ...        ...    ...    ...      ...
# 2149        20  공공·복지   1947   청소년지도사
# 2150        20  공공·복지   1948     특수교사
# 2151        20  공공·복지   1949    활동지원사
# 2152        20  공공·복지   1950  감각통합치료사
# 2153        20  공공·복지   1951    언어치료사
#
# [2154 rows x 4 columns]

# %%
job_dict = {}
for i in range(2154):
    job_dict[job_code['직무 코드'][i]] = job_code['직무 키워드명'][i]

# %%
job_dict
# Out:
# {2205: '기획',
#  2225: '경영관리',
#  1652: '경영분석',
#  1624: '게임기획',
#  1625: '경영기획',
#  1653: '경영컨설팅',
#  1654: '경영혁신(PI)',
#  1626: '광고기획',
#  1627: '교육기획',
#  1655: '금융컨설팅',
#  1656: '레벨디자인',
#  1628: '기술기획',
#  1657: '리서치',
#  1629: '마케팅기획',
#  1658: '데이터분석',
#  1630: '문화기획',
#  1659: '사업개발',
#  1631: '법인장',
#  1632: '브랜드기획',
#  1660: '사업관리',
#  1661: '사업제휴',
#  1633: '사업기획',
#  1634: '상품기획',
#  1662: '스토리보드',
#  1663: '시장조사',
#  1635: '서비스기획',
#  1636: '앱기획',
#  1664: '신사업기획',
#  1665: '신사업발굴',
#  1637: '웹기획',
#  1666: '실적관리',
#  1638: '인사기획',
#  1667: '엑셀러레이팅',
#  1639: '전략기획',
#  1668: '예산관리',
#  1640: '지점관리자',
#  1641: '출판기획',
#  1669: '인큐베이팅',
#  1670: '자료조사',
#  1642: '컨설턴트',
#  1643: '행사기획',
#  1671: '조직관리',
#  1672: '지속가능경영',
#  1644: 'CEO',
#  1673: '창업컨설팅',
#  1645: 'COO',
#  1674: '타당성검토',
#  1646: 'CTO',
#  1675: '투자전략',
#  1647: 'IT컨설팅',
#  1648: 'PL(프로젝트리더)',
#  1676: '트렌드분석',
#  1677: '프로토타이핑',
#  1649: 'PM(프로젝트매니저)',
#  1650: 'PMO',
#  1678: '해외법인관리',
#  1679: 'BPR',
# ...

# %%
train
# Out:
#             id  d_l_match_yn  d_m_match_yn  d_s_match_yn  h_l_match_yn  \
# 0            0          True          True          True         False
# 1            1         False         False         False          True
# 2            2         False         False         False          True
# 3            3         False         False         False          True
# 4            4          True          True          True         False
# ...        ...           ...           ...           ...           ...
# 501946  501946         False         False         False          True
# 501947  501947          True          True         False          True
# 501948  501948          True          True          True          True
# 501949  501949          True         False         False          True
# 501950  501950          True          True          True          True
#
#         h_m_match_yn  h_s_match_yn  person_attribute_a  person_attribute_a_1  \
# ...

# %%
for target in train.columns:
    train[target] = train[target].map(job_dict)

# %%
train
# Out:
#          id d_l_match_yn d_m_match_yn d_s_match_yn h_l_match_yn h_m_match_yn  \
# 0       NaN          NaN          NaN          NaN          NaN          NaN
# 1       NaN          NaN          NaN          NaN          NaN          NaN
# 2       NaN          NaN          NaN          NaN          NaN          NaN
# 3       NaN          NaN          NaN          NaN          NaN          NaN
# 4       NaN          NaN          NaN          NaN          NaN          NaN
# ...     ...          ...          ...          ...          ...          ...
# 501946  NaN          NaN          NaN          NaN          NaN          NaN
# 501947  NaN          NaN          NaN          NaN          NaN          NaN
# 501948  NaN          NaN          NaN          NaN          NaN          NaN
# 501949  NaN          NaN          NaN          NaN          NaN          NaN
# 501950  NaN          NaN          NaN          NaN          NaN          NaN
#
# ...

# %%
for target in train.columns:
    print(train[target][:10])
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: id, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: d_l_match_yn, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: d_m_match_yn, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: d_s_match_yn, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: h_l_match_yn, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# Name: h_m_match_yn, dtype: object
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# ...

# %%
train = train.dropna(axis=0)

# %%
train
# Out:
# Empty DataFrame
# Columns: [id, d_l_match_yn, d_m_match_yn, d_s_match_yn, h_l_match_yn, h_m_match_yn, h_s_match_yn, person_attribute_a, person_attribute_a_1, person_attribute_b, person_prefer_c, person_prefer_d_1, person_prefer_d_2, person_prefer_d_3, person_prefer_e, person_prefer_f, person_prefer_g, person_prefer_h_1, person_prefer_h_2, person_prefer_h_3, contents_attribute_i, contents_attribute_a, contents_attribute_j_1, contents_attribute_j, contents_attribute_c, contents_attribute_k, contents_attribute_l, contents_attribute_d, contents_attribute_m, contents_attribute_e, contents_attribute_h, person_rn, contents_rn, contents_open_dt, target]
# Index: []
#
# [0 rows x 35 columns]
